# %%
import pandas as pd

# %%
df = pd.read_csv("students.csv")

# %%
df.describe()
# Out:
#        Math_Score  Reading_Score  Writing_Score  Placement_Score    Club_Join  \
# count  143.000000     143.000000     144.000000       139.000000   142.000000
# mean    69.909091      85.062937      70.131944        85.028777  2022.176056
# std     13.840087       5.953123       6.232384         5.779703     1.400604
# min      0.000000      75.000000      60.000000        75.000000  2020.000000
# 25%     64.000000      80.000000      65.000000        80.000000  2021.000000
# 50%     70.000000      86.000000      70.000000        86.000000  2022.000000
# 75%     75.000000      90.000000      76.000000        90.000000  2023.000000
# max    200.000000      95.000000      80.000000        95.000000  2024.000000
#
#        Placement_Offer
# count       144.000000
# mean          2.569444
# std           1.068643
# min           1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           3.000000
# max          10.000000

# %%
df.isnull().sum()
# Out:
# Math_Score          6
# Reading_Score       6
# Writing_Score       5
# Placement_Score    10
# Club_Join           7
# Placement_Offer     5
# dtype: int64

# %%
a= df.Math_Score.mean()

# %%
df.Math_Score.fillna(a,inplace= True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13200\2572511151.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Math_Score.fillna(a,inplace= True)

# %%
b = df.Writing_Score.mean()

# %%
b
# Out:
# np.float64(70.13194444444444)

# %%
df.Writing_Score.fillna(b,inplace= True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13200\427952811.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Writing_Score.fillna(b,inplace= True)

# %%
c = df.Reading_Score.min()

# %%
df.Reading_Score.fillna(c,inplace= True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13200\812948862.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Reading_Score.fillna(c,inplace= True)

# %%
a = df.Placement_Score.max()

# %%
df.Placement_Score.fillna(a,inplace= True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13200\3355935644.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Placement_Score.fillna(a,inplace= True)

# %%
df.isnull().sum()
# Out:
# Math_Score         0
# Reading_Score      0
# Writing_Score      0
# Placement_Score    0
# Club_Join          7
# Placement_Offer    5
# dtype: int64

# %%
df.columns
# Out:
# Index(['Math_Score', 'Reading_Score', 'Writing_Score', 'Placement_Score',
#        'Club_Join', 'Placement_Offer'],
#       dtype='object')

# %%
df.boxplot(column=['Math_Score', 'Reading_Score', 'Writing_Score', 'Placement_Score'])
# Out:
# <Axes: >

# %%
import numpy as np
Q1 = np.percentile(df['Math_Score'], 25)
Q3 = np.percentile(df['Math_Score'], 75)

IQR = Q3 - Q1

# %%
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

print("Lower Limit:", lower)
print("Upper Limit:", upper)
# Out:
# Lower Limit: 47.5
# Upper Limit: 91.5

# %%
outliers = df[(df['Math_Score'] < lower) | (df['Math_Score'] > upper)]
print(outliers)
# Out:
#      Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join  \
# 141       200.0           89.0           79.0             75.0     2023.0
# 145         0.0           82.0           73.0             93.0     2020.0
#
#      Placement_Offer
# 141              2.0
# 145             10.0

# %%
df = df.drop(df[(df['Math_Score'] < lower) | 
                (df['Math_Score'] > upper)].index)

# %%
import matplotlib.pyplot as plt

df.boxplot(column=['Math_Score',
                   'Reading_Score',
                   'Writing_Score',
                   'Placement_Score'])

plt.show()
